# %%
#Top universities
from PIL import Image

#read the image
harvard = ("Harvard.jpg")
massachusest = Image.open("Massachusest.jpg")
stanford = Image.open("Stanford.jpg")
berkeley = Image.open("Berkeley.jpg")
oxford = Image.open("Oxford.jpg")
columbia = Image.open("Columbia.jpg")
colifornia = Image.open("Colifornia.jpg")
washington = Image.open("Washington.jpg")
a = "Harvard"
b = "Massachusest"
c = "Stanford"
d = "Berkeley"
e = "Oxford"
f = "Columbia"
g = "Colifornia"
h = "Washington"

university = input("Dunyoning Top 8 Universitetlari haqida ma`lumot beramiz, qaysi biriga o`qish qiziqishini bildirasiz?: ")

if university == "harvard":
    harvard.show()
    print(f" University{a}")
elif university == "massachusest":
    massachusest.show()
    print(f" University{b}")
elif university == "stanford":
    stanford.show()
    print(f"University{c}")
elif university == "berkeley":
    berkeley.show()
    print(f"University{d}")
elif university == "oxford":
    oxford.show()
    print(f"University {e}")
elif university == "columbia":
    columbia.show()
    print(f"University {f}")
elif university == "colifornia":
    colifornia.show()
    print(f"University {g}")
elif university == "washington":
    washington.show()
    print(f"University {h}")
    
else:
   
    print(f" Siz tanlagan universitet kuchli 8talikka kirmaydi")
# Out:
# Dunyoning Top 8 Universitetlari haqida ma`lumot beramiz, qaysi biriga o`qish qiziqishini bildirasiz?: columbia
# University Columbia

# %%
import matplotlib.pyplot as plt

x=["Hrvrd","Mschts","Stfrd","Cal-Ber","Oxfd.","Clmb","Clfrn","Wshtn"]
y=[22947,21376,20914,19910,18975,15455,11838,18376]
c=["red","orange","grey","black","purple","magenta","yellow","green",]
plt.bar(x,y, label="Bars1",width=0.8, color=c)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Top 8 universities of World\n Entered students')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
 
# Create bars
barWidth = 0.9
bars1 = [3, 3, 1]
bars2 = [4, 2, 3]
bars3 = [4, 6, 7, 10, 4, 4]
bars4 = bars1 + bars2 + bars3
 
# The X position of bars
r1 = [1,5,9]
r2 = [2,6,10]
r3 = [3,4,7,8,11,12]
r4 = r1 + r2 + r3
 
# Create barplot
plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='PhDs')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='Masters')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='Bachelors')
# Note: the barplot could be created easily. See the barplot section for other examples.
 
# Create legend
plt.legend()
 
# Text below each barplot with a rotation at 90°
plt.xticks([r + barWidth for r in range(len(r4))], ['Satnford', 'Berkeley', 'Harvard', 'Washington', 'Washington', 'Colifornia', 'Stanford', 'Oxford', 'Massachusetts', 'Massachusetts', 'Colifornia', 'Oxfrod'], rotation=90)
 
# Create labels
label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']
 
# Text on the top of each bar
for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)

# Adjust the margins
plt.subplots_adjust(bottom= 0.2, top = 0.98)
 
# Show graphic
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
df=pd.DataFrame({'x_values': range(1,11), 'y1_values': np.random.randn(10), 'y2_values': np.random.randn(10)+range(1,11), 'y3_values': np.random.randn(10)+range(11,21) })
 
# multiple line plots
plt.plot( 'x_values', 'y1_values', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4 ,label="PhD")
plt.plot( 'x_values', 'y2_values', data=df, marker='', color='olive', linewidth=2, label="Masters")
plt.plot( 'x_values', 'y3_values', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="Bachelors")

# show legend
plt.legend()

# show graph
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [52356,45624,43000,44000,56000,48000,57776]
  
plt.plot(Year, student_applying, color='red', marker='o')
plt.title('Harvard students applying', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Student applying', fontsize=14)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [11376,14376,13568,14978,13265,14285,15632]
  
plt.plot(Year, student_applying, color='orange', marker='o')
plt.title('Massachusetts Institute of Technology. students applying', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Student applying', fontsize=14)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [12579,14376,16914,14978,17265,17285,18232]
  
plt.plot(Year, student_applying, color='grey', marker='o')
plt.title('stanford university students applying', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Student applying', fontsize=14)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [39579,39376,41110,39978,40265,41285,41232]
  
plt.plot(Year, student_applying, color='black', marker='o')
plt.title('University of California, Berkeley students applying', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Student applying', fontsize=15)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [29579,30376,31455,28978,30222,33285,35232]
  
plt.plot(Year, student_applying, color='magenta', marker='o')
plt.title('Columbia University university students applying', fontsize=14, color="magenta")
plt.xlabel('Year', fontsize=14, color="magenta")
plt.ylabel('Student applying', fontsize=15, color="magenta")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [19579,18376,23975,21978,22265,23285,25232]
  
plt.plot(Year, student_applying, color='blue', marker='o')
plt.title('Oxford university students applying', fontsize=14, color="blue")
plt.xlabel('Year', fontsize=14, color="blue")
plt.ylabel('Student applying', fontsize=15, color="blue")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [42579,44947,38975,42978,39265,40285,41232]
  
plt.plot(Year, student_applying, color='green', marker='o')
plt.title('University of California students applying', fontsize=14, color="green")
plt.xlabel('Year', fontsize=14, color="green")
plt.ylabel('Student applying', fontsize=15, color="green")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [28579,30947,29975,32978,30265,31455,31232]
  
plt.plot(Year, student_applying, color='maroon', marker='o')
plt.title('Columbia University students applying', fontsize=14, color="maroon")
plt.xlabel('Year', fontsize=14, color="maroon")
plt.ylabel('Student applying', fontsize=15, color="maroon")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
   
Year = [2015,2016,2017,2018,2019,2020,2021]
student_applying = [13579,15155,15975,14978,17265,16455,17202]
  
plt.plot(Year, student_applying, color='lime', marker='o')
plt.title('Washington University  students applying', fontsize=14, color="lime")
plt.xlabel('Year', fontsize=14, color="lime")
plt.ylabel('Student applying', fontsize=15, color="lime")
plt.grid(True)
plt.show()

# %%
import pandas
df = pandas.read_csv('kerak.csv', 
            index_col='Universities', 
            parse_dates=['Country'], 
            header=1, 
            names=['Universities', 'Country','National Rank', 'Quality of education'])
print(df)
# Out:
#                                       Country  National Rank  \
# Universities
# Massachusetts Institute of Technology     USA              3
#  Stanford  University                     USA              2
# University of California--Berkeley        USA             10
# University of Oxford                       UK              8
# Columbia University                        UK              9
# California Institute of Technology        USA              5
# University of Washington                  USA              4
#
#                                        Quality of education
# Universities
# Massachusetts Institute of Technology                     4
#  Stanford  University                                     6
# University of California--Berkeley                        8
# University of Oxford                                      5
# Columbia University                                       2
# California Institute of Technology                        9
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings  
warnings.filterwarnings('ignore')


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
snc_df= pd.read_csv('cwurData.csv')
snc_df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
times  = pd.read_csv('cwurData.csv', index_col='world_rank')                         
times.head(8)
# Out:
#                                       institution         country  \
# world_rank
# 1                              Harvard University             USA
# 2           Massachusetts Institute of Technology             USA
# 3                             Stanford University             USA
# 4                         University of Cambridge  United Kingdom
# 5              California Institute of Technology             USA
# 6                            Princeton University             USA
# 7                            University of Oxford  United Kingdom
# 8                                 Yale University             USA
#
#             national_rank  quality_of_education  alumni_employment  \
# world_rank
# 1                       1                     7                  9
# 2                       2                     9                 17
# 3                       3                    17                 11
# 4                       1                    10                 24
# ...
